# %% [markdown]
# # GRMP Attack Experiment - Google Colab (Simple Version)
#
# This is a simplified version that directly runs `main.py`, similar to your original approach.
#
# ## Quick Start
#
# 1. **Upload Files**: Upload all Python files to Colab
# 2. **Enable GPU**: Runtime → Change runtime type → GPU
# 3. **Run the cells below**
#
# ## Note
#
# This simple version uses the default configuration from `main.py`.
# For interactive configuration and result viewing, use `GRMP_Attack_Colab.ipynb` instead.

# %% [markdown]
# ## Step 1: Install Dependencies

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ## Step 2: Run Experiment
#
# This will run the experiment using the default configuration in `main.py`.

# %%
# !python main.py

# %% [markdown]
# ## Step 3: View Results (Optional)

# %%
# List result files
# !ls -lh results/

# %%
# Display visualizations in notebook
from IPython.display import Image, display
from pathlib import Path

results_dir = Path("results")
figures = list(results_dir.glob("*_figure*.png"))

if figures:
    print("📊 Generated Visualizations:")
    for fig_path in sorted(figures):
        print(f"\n{fig_path.name}")
        display(Image(str(fig_path)))
else:
    print("⚠️  No visualization files found.")
